# %% [markdown]
# # MUTUI-GPT (Dove gpt sta solo nel nome)

# %%
import pandas as pd

df = pd.read_csv('..\\data\\08883_20230630.dsv',sep=';')

df.head(10)
# Out:
# C:\Users\e.cominato\AppData\Local\Temp\ipykernel_15912\3191063682.py:3: DtypeWarning: Columns (45,59,72,170,175,178,179,188,202,226,257,258) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('..\\data\\08883_20230630.dsv',sep=';')
#   DATA_RIFERIMENTO  ABI_BANCA    RAPPORTO  CAG_INTESTATARIO  \
# 0        30-GIU-23       8883  4292762065        1454177904
# 1        30-GIU-23       8883  2030292038         109162965
# 2        30-GIU-23       8883  1269141168        1303584783
# 3        30-GIU-23       8883  2151422428        1949845952
# 4        30-GIU-23       8883  2656079450        4138901064
# 5        30-GIU-23       8883  4170106445        3292007500
# 6        30-GIU-23       8883  1964112797        1949845952
# 7        30-GIU-23       8883   299300225        3210740881
# 8        30-GIU-23       8883  1690975960        3336123696
# 9        30-GIU-23       8883  3299930122        2011534661
#
# ...
